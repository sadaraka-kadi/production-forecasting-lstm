# %%
from plot_module import load_plot
import pandas as pd

# %% [markdown]
# ## Monthly Production and 12-Month Rolling Average

# %%
load_plot('Monthly production');

# %% [markdown]
# ## Actual vs Predicted Plots

# %% [markdown]
# #### Naive Forecast

# %%
load_plot('Naive forecast');

# %% [markdown]
# #### EWMA

# %%
load_plot('EWMA');

# %% [markdown]
# #### SES

# %%
load_plot('SES');

# %% [markdown]
# #### Holt

# %%
load_plot('Holt');

# %% [markdown]
# #### Holt-Winters(Additive Trend + Additive Seasonality)

# %%
load_plot('hw_add');

# %% [markdown]
# #### Holt-Winters(Additive Trend + Multiplicative Seasonality)

# %%
load_plot('hw_add_mul');

# %% [markdown]
# #### Holt-Winters(Multiplicative Trend + Multiplicative Seasonality)

# %%
load_plot('hw_mul');

# %% [markdown]
# #### ARIMA (0,1,0)

# %%
load_plot('ARIMA(0,1,0)');

# %% [markdown]
# #### ARIMA (1,1,0)

# %%
load_plot('ARIMA(1,1,0)');

# %% [markdown]
# #### SARIMA (0,1,1)(1,0,1,12)

# %%
load_plot('SARIMA(0,1,1)(1,0,1,12)');

# %% [markdown]
# #### SARIMA (1,1,0)(2,0,0,12)

# %%
load_plot('SARIMA(1,1,0)(2,0,0,12)');

# %% [markdown]
# #### Linear Regression

# %%
load_plot('LR');

# %% [markdown]
# #### SVR

# %%
load_plot('SVR');

# %% [markdown]
# #### Random Forest Regression

# %%
load_plot('RF');

# %% [markdown]
# #### LSTM

# %%
load_plot('LSTM');

# %% [markdown]
# ### Model Comparison

# %%
# Metrics transferred from previous notebooks
df_baseline = pd.DataFrame({
    'Models': ['Naive Forecast', 'EWMA', 'SES', 'Holt', 'Holt-Winters(Additive)', 'Holt-Winters(Additive Trend + Multiplicative Seasonality)', 'Holt-Winters(Multiplicative)'],
    'Train RMSE': [6673210.31, 4937168.76, 5701867.16, 6273553.92, 5255490.72, 5417331.69, 5413625.40], 
    'Train MAE': [4934792.11, 3975626.41, 4355431.18, 4685423.63, 3528012.86, 3635092.84, 3621779.88],
    'Train R^2': [0.81, 0.90, 0.86, 0.84, 0.88, 0.88, 0.88], 
    'Test RMSE': [7925857.24, 4224877.29, 5213051.49, 8624220.88, 6737046.93, 7501740.07, 8120349.21], 
    'Test MAE': [7054035.16, 3548693.13, 4335954.49, 6686203.89, 5643690.09, 6566245.66, 7167787.92],
    'Test R^2': [-1.57, 0.26, -0.11, -2.04, -0.85, -1.30, -1.70],
})

df_arima = pd.DataFrame({
    'Models': ['ARIMA (0,1,0)', 'ARIMA (1,1,0)', 'SARIMA (0,1,1)(1,0,1,12)', 'SARIMA (1,1,0)(2,0,0,12)'],
    'RMSE': [5795362.87, 5574067.28, 6053430.48, 6928738.44],
    'R2': [-0.37, -0.27, -0.50, -0.96], 
})

df_ml = pd.DataFrame({
    'Models': ['Linear Regression', 'SVR', 'Random Forest', 'LSTM'],
    'One-Step Test MAPE': [0.0018, 0.0025, 0.0023, 0.0040],
    'Multi-Step Test MAPE': [0.0028, 0.0034, 0.0014, 0.0036], 
    'Multi-Output Test MAPE': [0.0029, 0.0019, 0.0032, 0.0031],
})

# %% [markdown]
# #### Baseline Models Comparison

# %%
df_baseline.style.highlight_max(color="lightgreen", axis=0)\
        .highlight_min(color="lightcoral", axis=0)
# Out:
# <style type="text/css">
# #T_facbd_row0_col1, #T_facbd_row0_col2, #T_facbd_row1_col3, #T_facbd_row1_col6, #T_facbd_row2_col0, #T_facbd_row3_col4, #T_facbd_row6_col5 {
#   background-color: lightgreen;
# }
# #T_facbd_row0_col3, #T_facbd_row1_col0, #T_facbd_row1_col1, #T_facbd_row1_col4, #T_facbd_row1_col5, #T_facbd_row3_col6, #T_facbd_row4_col2 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_facbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_facbd_level0_col0" class="col_heading level0 col0" >Models</th>
#       <th id="T_facbd_level0_col1" class="col_heading level0 col1" >Train RMSE</th>
#       <th id="T_facbd_level0_col2" class="col_heading level0 col2" >Train MAE</th>
#       <th id="T_facbd_level0_col3" class="col_heading level0 col3" >Train R^2</th>
#       <th id="T_facbd_level0_col4" class="col_heading level0 col4" >Test RMSE</th>
#       <th id="T_facbd_level0_col5" class="col_heading level0 col5" >Test MAE</th>
#       <th id="T_facbd_level0_col6" class="col_heading level0 col6" >Test R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_facbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_facbd_row0_col0" class="data row0 col0" >Naive Forecast</td>
#       <td id="T_facbd_row0_col1" class="data row0 col1" >6673210.310000</td>
#       <td id="T_facbd_row0_col2" class="data row0 col2" >4934792.110000</td>
#       <td id="T_facbd_row0_col3" class="data row0 col3" >0.810000</td>
#       <td id="T_facbd_row0_col4" class="data row0 col4" >7925857.240000</td>
#       <td id="T_facbd_row0_col5" class="data row0 col5" >7054035.160000</td>
#       <td id="T_facbd_row0_col6" class="data row0 col6" >-1.570000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_facbd_row1_col0" class="data row1 col0" >EWMA</td>
#       <td id="T_facbd_row1_col1" class="data row1 col1" >4937168.760000</td>
#       <td id="T_facbd_row1_col2" class="data row1 col2" >3975626.410000</td>
#       <td id="T_facbd_row1_col3" class="data row1 col3" >0.900000</td>
#       <td id="T_facbd_row1_col4" class="data row1 col4" >4224877.290000</td>
#       <td id="T_facbd_row1_col5" class="data row1 col5" >3548693.130000</td>
#       <td id="T_facbd_row1_col6" class="data row1 col6" >0.260000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_facbd_row2_col0" class="data row2 col0" >SES</td>
#       <td id="T_facbd_row2_col1" class="data row2 col1" >5701867.160000</td>
#       <td id="T_facbd_row2_col2" class="data row2 col2" >4355431.180000</td>
#       <td id="T_facbd_row2_col3" class="data row2 col3" >0.860000</td>
#       <td id="T_facbd_row2_col4" class="data row2 col4" >5213051.490000</td>
#       <td id="T_facbd_row2_col5" class="data row2 col5" >4335954.490000</td>
#       <td id="T_facbd_row2_col6" class="data row2 col6" >-0.110000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_facbd_row3_col0" class="data row3 col0" >Holt</td>
#       <td id="T_facbd_row3_col1" class="data row3 col1" >6273553.920000</td>
#       <td id="T_facbd_row3_col2" class="data row3 col2" >4685423.630000</td>
#       <td id="T_facbd_row3_col3" class="data row3 col3" >0.840000</td>
#       <td id="T_facbd_row3_col4" class="data row3 col4" >8624220.880000</td>
#       <td id="T_facbd_row3_col5" class="data row3 col5" >6686203.890000</td>
#       <td id="T_facbd_row3_col6" class="data row3 col6" >-2.040000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_facbd_row4_col0" class="data row4 col0" >Holt-Winters(Additive)</td>
#       <td id="T_facbd_row4_col1" class="data row4 col1" >5255490.720000</td>
#       <td id="T_facbd_row4_col2" class="data row4 col2" >3528012.860000</td>
#       <td id="T_facbd_row4_col3" class="data row4 col3" >0.880000</td>
#       <td id="T_facbd_row4_col4" class="data row4 col4" >6737046.930000</td>
#       <td id="T_facbd_row4_col5" class="data row4 col5" >5643690.090000</td>
#       <td id="T_facbd_row4_col6" class="data row4 col6" >-0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_facbd_row5_col0" class="data row5 col0" >Holt-Winters(Additive Trend + Multiplicative Seasonality)</td>
#       <td id="T_facbd_row5_col1" class="data row5 col1" >5417331.690000</td>
#       <td id="T_facbd_row5_col2" class="data row5 col2" >3635092.840000</td>
#       <td id="T_facbd_row5_col3" class="data row5 col3" >0.880000</td>
#       <td id="T_facbd_row5_col4" class="data row5 col4" >7501740.070000</td>
#       <td id="T_facbd_row5_col5" class="data row5 col5" >6566245.660000</td>
#       <td id="T_facbd_row5_col6" class="data row5 col6" >-1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_facbd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_facbd_row6_col0" class="data row6 col0" >Holt-Winters(Multiplicative)</td>
#       <td id="T_facbd_row6_col1" class="data row6 col1" >5413625.400000</td>
#       <td id="T_facbd_row6_col2" class="data row6 col2" >3621779.880000</td>
#       <td id="T_facbd_row6_col3" class="data row6 col3" >0.880000</td>
#       <td id="T_facbd_row6_col4" class="data row6 col4" >8120349.210000</td>
#       <td id="T_facbd_row6_col5" class="data row6 col5" >7167787.920000</td>
#       <td id="T_facbd_row6_col6" class="data row6 col6" >-1.700000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### ARIMA Models Comparison

# %%
df_arima.style.highlight_max(color="lightgreen", axis=0)\
        .highlight_min(color="lightcoral", axis=0)
# Out:
# <style type="text/css">
# #T_9d56d_row0_col0, #T_9d56d_row1_col1, #T_9d56d_row3_col2 {
#   background-color: lightcoral;
# }
# #T_9d56d_row1_col2, #T_9d56d_row3_col0, #T_9d56d_row3_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d56d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d56d_level0_col0" class="col_heading level0 col0" >Models</th>
#       <th id="T_9d56d_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_9d56d_level0_col2" class="col_heading level0 col2" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d56d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d56d_row0_col0" class="data row0 col0" >ARIMA (0,1,0)</td>
#       <td id="T_9d56d_row0_col1" class="data row0 col1" >5795362.870000</td>
#       <td id="T_9d56d_row0_col2" class="data row0 col2" >-0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_9d56d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d56d_row1_col0" class="data row1 col0" >ARIMA (1,1,0)</td>
#       <td id="T_9d56d_row1_col1" class="data row1 col1" >5574067.280000</td>
#       <td id="T_9d56d_row1_col2" class="data row1 col2" >-0.270000</td>
#     </tr>
#     <tr>
#       <th id="T_9d56d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d56d_row2_col0" class="data row2 col0" >SARIMA (0,1,1)(1,0,1,12)</td>
#       <td id="T_9d56d_row2_col1" class="data row2 col1" >6053430.480000</td>
#       <td id="T_9d56d_row2_col2" class="data row2 col2" >-0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_9d56d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d56d_row3_col0" class="data row3 col0" >SARIMA (1,1,0)(2,0,0,12)</td>
#       <td id="T_9d56d_row3_col1" class="data row3 col1" >6928738.440000</td>
#       <td id="T_9d56d_row3_col2" class="data row3 col2" >-0.960000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Machine Learning Models Comparison

# %%
df_ml.style.highlight_max(color="lightgreen", axis=0)\
        .highlight_min(color="lightcoral", axis=0)
# Out:
# <style type="text/css">
# #T_5b73e_row0_col1, #T_5b73e_row1_col3, #T_5b73e_row2_col2, #T_5b73e_row3_col0 {
#   background-color: lightcoral;
# }
# #T_5b73e_row1_col0, #T_5b73e_row2_col3, #T_5b73e_row3_col1, #T_5b73e_row3_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5b73e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b73e_level0_col0" class="col_heading level0 col0" >Models</th>
#       <th id="T_5b73e_level0_col1" class="col_heading level0 col1" >One-Step Test MAPE</th>
#       <th id="T_5b73e_level0_col2" class="col_heading level0 col2" >Multi-Step Test MAPE</th>
#       <th id="T_5b73e_level0_col3" class="col_heading level0 col3" >Multi-Output Test MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b73e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b73e_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_5b73e_row0_col1" class="data row0 col1" >0.001800</td>
#       <td id="T_5b73e_row0_col2" class="data row0 col2" >0.002800</td>
#       <td id="T_5b73e_row0_col3" class="data row0 col3" >0.002900</td>
#     </tr>
#     <tr>
#       <th id="T_5b73e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b73e_row1_col0" class="data row1 col0" >SVR</td>
#       <td id="T_5b73e_row1_col1" class="data row1 col1" >0.002500</td>
#       <td id="T_5b73e_row1_col2" class="data row1 col2" >0.003400</td>
#       <td id="T_5b73e_row1_col3" class="data row1 col3" >0.001900</td>
#     </tr>
#     <tr>
#       <th id="T_5b73e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b73e_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_5b73e_row2_col1" class="data row2 col1" >0.002300</td>
#       <td id="T_5b73e_row2_col2" class="data row2 col2" >0.001400</td>
#       <td id="T_5b73e_row2_col3" class="data row2 col3" >0.003200</td>
#     </tr>
#     <tr>
#       <th id="T_5b73e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b73e_row3_col0" class="data row3 col0" >LSTM</td>
#       <td id="T_5b73e_row3_col1" class="data row3 col1" >0.004000</td>
#       <td id="T_5b73e_row3_col2" class="data row3 col2" >0.003600</td>
#       <td id="T_5b73e_row3_col3" class="data row3 col3" >0.003100</td>
#     </tr>
#   </tbody>
# </table>
