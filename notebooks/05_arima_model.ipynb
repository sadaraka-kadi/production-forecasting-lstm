# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv('Monthly_oil_data.csv', index_col='Production Date', parse_dates=True)

# %%
df.head()
# Out:
#                      Volume
# Production Date
# 2015-01-01       67515553.0
# 2015-02-01       61664960.0
# 2015-03-01       66342950.0
# 2015-04-01       67719040.0
# 2015-05-01       66484591.0

# %%
df.index.freq = 'MS'
df.plot(figsize=(16, 5));

# %% [markdown]
# ## Checking Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

def adf(x): 
    res = adfuller(x)
    print('Test Statistic:', res[0]) 
    print('P-Value:', res[1]) 

    if res[1] < 0.05: 
        print('Stationary')
    else:
        print('Non-Stationary') 

adf(df.Volume)
# Out:
# Test Statistic: -1.344737549600928
# P-Value: 0.6084645921750879
# Non-Stationary

# %% [markdown]
# ## Differencing

# %%
df['1stDiff'] = df['Volume'].diff() 
df['1stDiff'].plot(figsize=(16,5));
adf(df['1stDiff'].dropna())
# Out:
# Test Statistic: -4.890839964217605
# P-Value: 3.63347590898391e-05
# Stationary

# %% [markdown]
# ## ACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['Volume']);

# %%
plot_acf(df['1stDiff'],);

# %% [markdown]
# ## PACF

# %%
plot_pacf(df['Volume']);

# %%
plot_pacf(df['1stDiff']);

# %% [markdown]
# _The ACF and PACF results indicate that the original series is non-stationary, while the first-differenced series exhibits no significant autocorrelation. This suggests that the data follows a random walk process, and an ARIMA(0,1,0) model is appropriate._

# %% [markdown]
# ### Train/Test Split

# %%
Ntest = 12 
train = df.iloc[:-Ntest] 
test = df.iloc[-Ntest:]

# %% [markdown]
# ### ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
arima = ARIMA(train['Volume'], order=(0,1,0)) 
result_arima_010 = arima.fit()

# %%
def plot_fit_and_forecast(result, d, col='Volume'): 
    fig, ax = plt.subplots(figsize=(16,5)) 
    ax.plot(df[col], label='data') 

    train_pred = result.predict(start=train.index[d], end=train.index[-1]) 
    ax.plot(train.index[d:], train_pred, color='green', label='fitted') 

    prediction_result = result.get_forecast(Ntest) 
    conf_int = prediction_result.conf_int()
    lower, upper = conf_int[f'lower {col}'], conf_int[f'upper {col}'] 
    forecast = prediction_result.predicted_mean 
    ax.plot(test.index, forecast, label='forecast') 
    ax.fill_between(test.index, lower, upper, color='red', alpha=0.3)
    ax.legend()

# %%
plot_fit_and_forecast(result_arima_010, 1, col='Volume')

# %% [markdown]
# ### Auto-ARIMA

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(train['Volume'], start_p=0, start_q=0, max_p=3, max_q=3, d=1, seasonal=False,
                      suppress_warnings=True, trace=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3841.218, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3822.665, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3822.947, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3839.696, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3824.184, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3824.291, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3826.376, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3822.294, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3824.118, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3824.049, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3822.392, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3826.096, Time=0.29 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 1.172 seconds

# %%
arima = ARIMA(train['Volume'], order=(1,1,0)) 
result_arima_110 = arima.fit()
plot_fit_and_forecast(result_arima_110, 1, col='Volume')

# %%
model = pm.auto_arima(train['Volume'], start_p=0, start_q=0, max_p=5, max_q=5, d=1, seasonal=True,
                      suppress_warnings=True, trace=True, stepwise=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=3837.575, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3841.218, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=3822.633, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3823.387, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3839.696, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=3822.665, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=3821.749, Time=0.36 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=3822.707, Time=0.60 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=3823.151, Time=0.26 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=3837.067, Time=0.19 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=3823.549, Time=0.37 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=3824.103, Time=0.43 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=3823.150, Time=0.38 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=3825.443, Time=1.25 sec
#  ARIMA(1,1,0)(2,0,0)[12]             : AIC=3820.521, Time=0.24 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=3821.865, Time=0.10 sec
#  ARIMA(1,1,0)(2,0,1)[12]             : AIC=3818.600, Time=0.56 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=3817.687, Time=0.38 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=3822.303, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,2)[12]             : AIC=3818.426, Time=0.74 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=3822.294, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,2)[12]             : AIC=3821.694, Time=0.30 sec
#  ARIMA(1,1,0)(2,0,2)[12]             : AIC=3820.143, Time=1.11 sec
#  ARIMA(0,1,0)(1,0,1)[12]             : AIC=3835.681, Time=0.20 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=3819.362, Time=0.34 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=3819.325, Time=0.38 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=3817.428, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=3822.494, Time=0.15 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=3822.075, Time=0.11 sec
#  ARIMA(0,1,1)(2,0,1)[12]             : AIC=3818.311, Time=0.47 sec
#  ARIMA(0,1,1)(1,0,2)[12]             : AIC=3818.142, Time=0.61 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=3822.392, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,2)[12]             : AIC=3821.898, Time=0.31 sec
#  ARIMA(0,1,1)(2,0,0)[12]             : AIC=3820.683, Time=0.23 sec
#  ARIMA(0,1,1)(2,0,2)[12]             : AIC=3819.887, Time=1.15 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=3819.288, Time=0.34 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=3821.273, Time=0.37 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=3825.320, Time=0.28 sec
#
# Best model:  ARIMA(0,1,1)(1,0,1)[12]
# Total fit time: 13.466 seconds

# %%
model = pm.auto_arima(train['Volume'], start_p=0, start_q=0, max_p=5, max_q=5, d=1, seasonal=True,
                      suppress_warnings=True, trace=True, stepwise=False, m=12)
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3841.218, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=3840.876, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=3838.833, Time=0.22 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=3840.211, Time=0.09 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=3837.575, Time=0.17 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=3835.907, Time=0.44 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=3837.067, Time=0.19 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=3836.121, Time=0.38 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=3837.884, Time=0.72 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=3822.947, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3823.387, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=3823.154, Time=0.36 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=3823.500, Time=0.14 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=3825.320, Time=0.28 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=3825.037, Time=0.56 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=3823.150, Time=0.32 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=3825.112, Time=0.48 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=3826.814, Time=1.23 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=3824.575, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=3825.035, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=3824.854, Time=0.35 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=3825.157, Time=0.16 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=3826.939, Time=0.39 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=3826.762, Time=0.64 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=3824.892, Time=0.29 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=3826.843, Time=0.63 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=3825.645, Time=0.15 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=3826.208, Time=0.25 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=3826.258, Time=0.55 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=3826.238, Time=0.19 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=3828.208, Time=0.43 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=3826.110, Time=0.59 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=3827.535, Time=0.17 sec
#  ARIMA(0,1,4)(0,0,1)[12] intercept   : AIC=3828.133, Time=0.31 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=3828.211, Time=0.20 sec
#  ARIMA(0,1,5)(0,0,0)[12] intercept   : AIC=3829.667, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=3822.665, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=3822.976, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=3822.629, Time=0.29 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=3822.633, Time=0.12 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=3823.151, Time=0.25 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=3822.517, Time=0.49 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=3821.749, Time=0.31 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=3822.707, Time=0.55 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=3824.344, Time=1.09 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=3824.291, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=3824.754, Time=0.23 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=3824.543, Time=0.44 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=3824.651, Time=0.25 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=3826.524, Time=0.46 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=3825.763, Time=0.86 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=3824.103, Time=0.47 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=3825.919, Time=0.73 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=3825.562, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=3826.111, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=3826.051, Time=0.59 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=3825.892, Time=0.29 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=3827.142, Time=0.15 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=3827.754, Time=0.31 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=3827.551, Time=0.22 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=3829.066, Time=0.19 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=3824.184, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=3824.627, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=3824.330, Time=0.24 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=3824.340, Time=0.10 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=3825.386, Time=0.23 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=3824.650, Time=0.61 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=3823.549, Time=0.34 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=3824.827, Time=0.68 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=3826.376, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=3826.835, Time=0.34 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=3826.543, Time=0.87 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=3826.631, Time=0.40 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=3825.689, Time=2.47 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=3825.443, Time=2.78 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=3827.562, Time=0.38 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=3828.111, Time=1.14 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=3827.845, Time=1.83 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=2.08 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=3825.977, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=3826.473, Time=0.28 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=3826.384, Time=0.48 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=3826.243, Time=0.38 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=3827.707, Time=1.93 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=3825.727, Time=1.67 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=3827.833, Time=0.38 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=3828.347, Time=1.21 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=3828.126, Time=0.57 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=3828.889, Time=0.67 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=3827.759, Time=0.14 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=3828.202, Time=0.27 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=3827.989, Time=0.34 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=3829.230, Time=0.27 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=3828.966, Time=0.16 sec
#
# Best model:  ARIMA(1,1,0)(2,0,0)[12] intercept
# Total fit time: 46.891 seconds

# %% [markdown]
# ### SARIMA

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(train['Volume'], order=(0,1,1), seasonal_order=(1,0,1,12), enforce_stationarity=False,
                enforce_invertibility=False)

result_sarima_011_10112 = model.fit()
plot_fit_and_forecast(result_sarima_011_10112, 1, col='Volume')

# %%
model = SARIMAX(train['Volume'], order=(1,1,0), seasonal_order=(2,0,0,12), enforce_stationarity=False,
                enforce_invertibility=False)

result_sarima_110_20012 = model.fit()
plot_fit_and_forecast(result_sarima_110_20012, 1, col='Volume')

# %% [markdown]
# ### Residual Diagnostics

# %%
result_arima_010.plot_diagnostics(figsize=(16,12));

# %%
result_arima_110.plot_diagnostics(figsize=(16,12));

# %%
result_sarima_011_10112.plot_diagnostics(figsize=(16,12));

# %%
result_sarima_110_20012.plot_diagnostics(figsize=(16,12));

# %% [markdown]
# Residual diagnostics were performed to verify ARIMA assumptions. Residuals were centered around zero, uncorrelated, and approximately normally distributed, indicating the model adequately captured trends and seasonality.

# %% [markdown]
# ### Metrics

# %% [markdown]
# #### RMSE

# %%
def rmse (result): 
    forecast = result.forecast(Ntest)
    t = test['Volume'] 
    y = forecast 
    return np.sqrt(np.mean((t-y)**2))

# %%
print('RMSE ARIMA (0,1,0):',rmse(result_arima_010)) 
print('RMSE ARIMA (1,1,0):',rmse(result_arima_110))
print('RMSE SARIMA (0,1,1)(1,0,1,12):',rmse(result_sarima_011_10112)) 
print('RMSE SARIMA (1,1,0)(2,0,0,12):', rmse(result_sarima_110_20012))
# Out:
# RMSE ARIMA (0,1,0): 5795362.870161123
# RMSE ARIMA (1,1,0): 5574067.283580957
# RMSE SARIMA (0,1,1)(1,0,1,12): 6053430.481587058
# RMSE SARIMA (1,1,0)(2,0,0,12): 6928738.4439750165

# %% [markdown]
# #### R^2

# %%
from sklearn.metrics import r2_score 

def r2(result):
    forecast = result.forecast(Ntest) 
    t = test['Volume'] 
    y = forecast
    return r2_score(t, y)

# %%
print('R2 ARIMA (0,1,0):',r2(result_arima_010)) 
print('R2 ARIMA (1,1,0):',r2(result_arima_110))
print('R2 SARIMA (0,1,1)(1,0,1,12):',r2(result_sarima_011_10112)) 
print('R2 SARIMA (1,1,0)(2,0,0,12):', r2(result_sarima_110_20012))
# Out:
# R2 ARIMA (0,1,0): -0.3762677643410681
# R2 ARIMA (1,1,0): -0.273169080685036
# R2 SARIMA (0,1,1)(1,0,1,12): -0.5015672525555024
# R2 SARIMA (1,1,0)(2,0,0,12): -0.9672067423910333

# %% [markdown]
# ### Forecast Conclusion

# %% [markdown]
# _ARIMA(1,1,0) achieved the lowest RMSE (5,574,067) and is therefore the best-performing model._
# _SARIMA models did not improve performance, indicating weak or irregular seasonality in the data._
